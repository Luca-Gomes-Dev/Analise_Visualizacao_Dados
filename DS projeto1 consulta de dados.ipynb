# %% [markdown]
# <a href="https://colab.research.google.com/github/Luca-Gomes-Dev/Analise_Visualizacao_Dados/blob/main/DS%20projeto1%20consulta%20de%20dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Abrir Conexão do banco de dados
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db')

# %%
# Consulta dos dados no banco de dados
consulta_atividade = """

  SELECT
    fa.loyalty_number,
    fa.month,
    fa.flights_booked,
    fa.year
  FROM flight_activity fa
  WHERE
    fa.flights_booked > 10

"""
df_atividade = pd.read_sql_query( consulta_atividade, conn )

df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0          100727  2017      1              11                        0
# 1          100883  2017      1              11                        0
# 2          101515  2017      1              11                        0
# 3          101594  2017      1              11                        0
# 4          104353  2017      1              11                        6
#
#    total_flights  distance  points_accumulated  points_redeemed  \
# 0             11      1144               114.0                0
# 1             11      3124               312.0                0
# 2             11      1100               110.0                0
# 3             11      3399               339.0                0
# 4             17      1343               134.0                0
#
#    dollar_cost_points_redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %% [markdown]
# # EXERCICIOS AULA1

# %%
# Selecione as colunas : loyalty_number, country, city, gender, loyalty_card, salary da tabela flyght_loyalty_history

# Consulta dos dados no banco de dados
consulta_atividade = """

  SELECT
    flh.loyalty_number,
    flh.country,
    flh.city,
    flh.gender,
    flh.loyalty_card,
    flh.salary
  FROM flight_loyalty_history flh


"""
df_atividade = pd.read_sql_query( consulta_atividade, conn )

df_atividade.head()
# Out:
#    loyalty_number country       city  gender loyalty_card    salary
# 0          480934  Canada    Toronto  Female         Star   83236.0
# 1          549612  Canada   Edmonton    Male         Star       NaN
# 2          429460  Canada  Vancouver    Male         Star       NaN
# 3          608370  Canada    Toronto    Male         Star       NaN
# 4          530508  Canada       Hull    Male         Star  103495.0

# %%
# Selecione as colunas, porem, recupere somente as linhas cuja coluna gender é igual a Female
# Consulta dos dados no banco de dados
consulta_atividade = """

  SELECT
    flh.loyalty_number,
    flh.country,
    flh.city,
    flh.gender,
    flh.loyalty_card,
    flh.salary
  FROM flight_loyalty_history flh
  WHERE
    flh.gender = "Female"



"""
df_atividade = pd.read_sql_query( consulta_atividade, conn )

df_atividade.head()
# Out:
#    loyalty_number country          city  gender loyalty_card    salary
# 0          480934  Canada       Toronto  Female         Star   83236.0
# 1          927943  Canada       Toronto  Female         Star       NaN
# 2          852392  Canada      Montreal  Female         Star  100159.0
# 3          932823  Canada     Vancouver  Female         Star   66444.0
# 4          144514  Canada  Dawson Creek  Female         Star   49618.0

# %%
# Selecione as colunas : loyalty_number, month, year, distance, flights_booked,
# total_flights da tabela flight_activity e recupere somente as linhas cuja coluna fligths_booked é menor que 12

# Consulta dos dados no banco de dados
consulta_atividade = """

  SELECT
  fa.loyalty_number,
  fa.month,
  fa.year,
  fa.distance,
  fa.flights_booked,
  fa.total_flights
 FROM flight_activity fa
 WHERE
 fa.flights_booked > 10 AND fa.flights_booked < 12

"""
df_atividade = pd.read_sql_query( consulta_atividade, conn )

df_atividade.head()
# Out:
#    loyalty_number  month  year  distance  flights_booked  total_flights
# 0          100727      1  2017      1144              11             11
# 1          100883      1  2017      3124              11             11
# 2          101515      1  2017      1100              11             11
# 3          101594      1  2017      3399              11             11
# 4          104353      1  2017      1343              11             17
